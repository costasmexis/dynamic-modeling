# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from system_ode import PlotSolution, GetDataset, PlotPredictions
from machinelearning import main, plot_net_predictions

# %%
full_df = GetDataset(alpha=0.25)
PlotSolution(full_df)

# %%
train_df = full_df.iloc[:999].copy()

# %%
net, u_pred = main(train_df, full_df, num_epochs=30000)
# Out:
# Epoch 1/30000, Loss: 11.2374, Loss Data: 11.0939, Loss ODE: 0.1435, Loss IC: 0.0000
# mu_max: 0.50, alpha: 0.50
# Epoch 101/30000, Loss: 0.0826, Loss Data: 0.0532, Loss ODE: 0.0294, Loss IC: 0.0000
# mu_max: 0.45, alpha: 0.44
# Epoch 201/30000, Loss: 0.0550, Loss Data: 0.0348, Loss ODE: 0.0202, Loss IC: 0.0000
# mu_max: 0.47, alpha: 0.38
# Epoch 301/30000, Loss: 0.0462, Loss Data: 0.0330, Loss ODE: 0.0132, Loss IC: 0.0000
# mu_max: 0.47, alpha: 0.33
# Epoch 401/30000, Loss: 0.0383, Loss Data: 0.0266, Loss ODE: 0.0117, Loss IC: 0.0000
# mu_max: 0.49, alpha: 0.30
# Epoch 501/30000, Loss: 0.0291, Loss Data: 0.0222, Loss ODE: 0.0069, Loss IC: 0.0000
# mu_max: 0.51, alpha: 0.28
# Epoch 601/30000, Loss: 0.0223, Loss Data: 0.0175, Loss ODE: 0.0048, Loss IC: 0.0000
# mu_max: 0.53, alpha: 0.26
# Epoch 701/30000, Loss: 0.0193, Loss Data: 0.0146, Loss ODE: 0.0047, Loss IC: 0.0000
# mu_max: 0.55, alpha: 0.26
# Epoch 801/30000, Loss: 0.0270, Loss Data: 0.0121, Loss ODE: 0.0149, Loss IC: 0.0000
# mu_max: 0.57, alpha: 0.26
# Epoch 901/30000, Loss: 0.1065, Loss Data: 0.0181, Loss ODE: 0.0884, Loss IC: 0.0000
# mu_max: 0.58, alpha: 0.27
# Epoch 1001/30000, Loss: 0.0191, Loss Data: 0.0152, Loss ODE: 0.0038, Loss IC: 0.0000
# mu_max: 0.55, alpha: 0.25
# Epoch 1101/30000, Loss: 0.0154, Loss Data: 0.0122, Loss ODE: 0.0032, Loss IC: 0.0000
# mu_max: 0.57, alpha: 0.26
# Epoch 1201/30000, Loss: 0.0131, Loss Data: 0.0105, Loss ODE: 0.0026, Loss IC: 0.0000
# mu_max: 0.58, alpha: 0.26
# Epoch 1301/30000, Loss: 0.0112, Loss Data: 0.0090, Loss ODE: 0.0022, Loss IC: 0.0000
# mu_max: 0.60, alpha: 0.26
# Epoch 1401/30000, Loss: 0.0095, Loss Data: 0.0077, Loss ODE: 0.0019, Loss IC: 0.0000
# mu_max: 0.61, alpha: 0.27
# Epoch 1501/30000, Loss: 0.0081, Loss Data: 0.0065, Loss ODE: 0.0016, Loss IC: 0.0000
# mu_max: 0.62, alpha: 0.27
# Epoch 1601/30000, Loss: 0.0066, Loss Data: 0.0053, Loss ODE: 0.0013, Loss IC: 0.0000
# mu_max: 0.64, alpha: 0.27
# Epoch 1701/30000, Loss: 0.0054, Loss Data: 0.0044, Loss ODE: 0.0011, Loss IC: 0.0000
# mu_max: 0.65, alpha: 0.27
# Epoch 1801/30000, Loss: 0.0048, Loss Data: 0.0030, Loss ODE: 0.0018, Loss IC: 0.0000
# mu_max: 0.66, alpha: 0.27
# Epoch 1901/30000, Loss: 0.0049, Loss Data: 0.0028, Loss ODE: 0.0020, Loss IC: 0.0000
# mu_max: 0.67, alpha: 0.27
# Epoch 2001/30000, Loss: 0.0035, Loss Data: 0.0021, Loss ODE: 0.0014, Loss IC: 0.0000
# mu_max: 0.67, alpha: 0.26
# Epoch 2101/30000, Loss: 0.0019, Loss Data: 0.0015, Loss ODE: 0.0004, Loss IC: 0.0000
# mu_max: 0.68, alpha: 0.26
# Epoch 2201/30000, Loss: 0.0015, Loss Data: 0.0012, Loss ODE: 0.0003, Loss IC: 0.0000
# mu_max: 0.68, alpha: 0.26
# Epoch 2301/30000, Loss: 0.0014, Loss Data: 0.0011, Loss ODE: 0.0003, Loss IC: 0.0000
# mu_max: 0.69, alpha: 0.26
# Epoch 2401/30000, Loss: 0.0017, Loss Data: 0.0010, Loss ODE: 0.0007, Loss IC: 0.0000
# mu_max: 0.69, alpha: 0.26
# Epoch 2501/30000, Loss: 0.0017, Loss Data: 0.0007, Loss ODE: 0.0010, Loss IC: 0.0000
# mu_max: 0.69, alpha: 0.26
# Epoch 2601/30000, Loss: 0.0010, Loss Data: 0.0008, Loss ODE: 0.0002, Loss IC: 0.0000
# mu_max: 0.70, alpha: 0.26
# Epoch 2701/30000, Loss: 0.0014, Loss Data: 0.0008, Loss ODE: 0.0006, Loss IC: 0.0000
# mu_max: 0.70, alpha: 0.26
# Epoch 2801/30000, Loss: 0.0132, Loss Data: 0.0005, Loss ODE: 0.0127, Loss IC: 0.0000
# mu_max: 0.70, alpha: 0.26

# %%
print(f'mu_max = {net.mu_max.item()}')
print(f'alpha = {net.alpha.item()}')
# Out:
# mu_max = 0.43368256092071533
# alpha = 0.34261393547058105

# %%
plot_net_predictions(full_df=full_df, train_df=train_df, u_pred=u_pred)

# %%
sim_pred_df = GetDataset(mumax = net.mu_max.item(), alpha = net.alpha.item())
PlotPredictions(train_df, sim_pred_df)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
