# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from system_ode import PlotSolution, GetDataset, PlotPredictions
from machinelearning import main, plot_net_predictions

# %%
full_df = GetDataset()
PlotSolution(full_df)

# %%
train_df = full_df.iloc[:999].copy()

# %%
net, u_pred = main(train_df, full_df, num_epochs=30000)
# Out:
# Epoch 1/30000, Loss: 48.8745, Loss Data: 16.1524, Loss ODE: 0.0998, Loss IC: 32.6223
# mu_max: 0.30, alpha: 0.30
# Epoch 101/30000, Loss: 16.3238, Loss Data: 6.0693, Loss ODE: 0.2562, Loss IC: 9.9983
# mu_max: 0.30, alpha: 0.29
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 net, u_pred = main(train_df, full_df, num_epochs=30000)
#
# File ~/dynamic-modeling/induction/machinelearning.py:132, in main(train_df, full_df, num_epochs)
#     129 loss_ic = nn.MSELoss()(u_pred[0, :], u_train[0, :]) * w_ic
#     131 loss = loss_data + loss_ode + loss_ic
# --> 132 loss.backward()
#     133 optimizer.step()
#     135 if epoch % 100 == 0:
#
# File ~/env/main/lib/python3.10/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
# ...

# %%
plot_net_predictions(full_df=full_df, train_df=train_df, u_pred=u_pred)

# %%
sim_pred_df = GetDataset(net.mu_max.item())
PlotPredictions(train_df, sim_pred_df)
