# %%
import sys

sys.path.append("../")

from src.utils import get_data_and_feed
import matplotlib.pyplot as plt

FILENAME = "../data/data_processed.xlsx"
EXPERIMENT = "BR02"
S_IN = 1.43 * 200

# %%
full_df, feeds = get_data_and_feed(
    file_name=FILENAME, experiment=EXPERIMENT
)

plt.figure(figsize=(12, 6)) 
plt.scatter(full_df["RTime"], full_df["Glucose"], label="Glucose (g/L)", color='blue', marker='o', s=50, alpha=0.7, edgecolors='w')
plt.scatter(full_df["RTime"], full_df["Biomass"], label="Biomass (g/L)", color='green', marker='s', s=50, alpha=0.7, edgecolors='w')
plt.scatter(full_df["RTime"], 10 * full_df["Protein"], label="Protein (10 × mg/L)", color='red', marker='^', s=50, alpha=0.7, edgecolors='w')
plt.legend(fontsize=12)
plt.xlabel('Time (h)', fontsize=14)
plt.ylabel('Concentration', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
